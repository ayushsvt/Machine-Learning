# %%
import pandas as pd
import thompson as rif

# %%
df = pd.read_csv("https://raw.githubusercontent.com/digipodium/Datasets/main/reinforcement/Ads_CTR_Optimisation.csv")

# %%
for col in df:
    count = df[col].value_counts()
    print(count)
    print("---------")
# Out:
# 0    8297
# 1    1703
# Name: Ad 1, dtype: int64
# ---------
# 0    8705
# 1    1295
# Name: Ad 2, dtype: int64
# ---------
# 0    9272
# 1     728
# Name: Ad 3, dtype: int64
# ---------
# 0    8804
# 1    1196
# Name: Ad 4, dtype: int64
# ---------
# 0    7305
# 1    2695
# Name: Ad 5, dtype: int64
# ---------
# 0    9874
# 1     126
# Name: Ad 6, dtype: int64
# ---------
# 0    8888
# 1    1112
# Name: Ad 7, dtype: int64
# ---------
# 0    7909
# 1    2091
# Name: Ad 8, dtype: int64
# ---------
# 0    9048
# 1     952
# Name: Ad 9, dtype: int64
# ---------
# 0    9511
# 1     489
# Name: Ad 10, dtype: int64
# ---------

# %%
out = rif.UCB(df)       # Train the reinforcement

# %%
rif.plot(out)

# %%
out2 = rif.thompson(df)

# %%
rif.plot(out2)

# %%
def divide(x, y):
    try:
        result = x // y
    except ZeroDivisionError:
        print("Sorry ! You are dividing by zero ")
    else:
        print("Yeah ! Your answer is :", result)
divide(25, 4)
divide(3, 0)
# Out:
# Yeah ! Your answer is : 6
# Sorry ! You are dividing by zero

# %%
def divide(x, y):
    try:
        result = x // y
    except ZeroDivisionError:
        print("Sorry ! You are dividing by zero ")
    else:
        print("Yeah ! Your answer is :", result)
    finally:  
        print('This is always executed')  
divide(452, 8)
divide(85, 0)
# Out:
# Yeah ! Your answer is : 56
# This is always executed
# Sorry ! You are dividing by zero
# This is always executed

# %%
import re

# %%
import re

txt = "Hello, Welcome to Digipodium"
x = re.findall("o", txt)
print(x)
# Out:
# ['o', 'o', 'o', 'o']

# %%
import re

txt = "Hello, Welcome to digipodium"
x = re.search("di", txt)
print(x)
# Out:
# <re.Match object; span=(18, 20), match='di'>

# %%
import re

txt = "Hello, Welcome to digipodium"
x = re.split("i", txt)
print(x)
# Out:
# ['Hello, Welcome to d', 'g', 'pod', 'um']

# %%
import re

txt = "Hello, Welcome to digipodium"
x = re.sub("di" ,"DI", txt)
print(x)
# Out:
# Hello, Welcome to DIgipoDIum

# %%
import re

txt = "Hello, Welcome to digipodium"
x = re.search(r"\bWel\w+", txt)
print(x.span())
# Out:
# (7, 14)

# %%
import re

txt = "Hello, Welcome to digipodium"
x = re.search("We", txt)
print(x.string)
# Out:
# Hello, Welcome to digipodium

# %%
import re

txt = "Hello, Welcome to digipodium"
x = re.match("H", txt)
print(x.string)
# Out:
# Hello, Welcome to digipodium

# %%
import re

txt = "Hello, Welcome to digipodium"
x = re.search(r"\bdi\w+", txt)
print(x.group())
# Out:
# digipodium

# %%
import re

txt = "Hello, Welcome to digipodium"
x = re.match(r"\bl\w+", txt)
print(x.group())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Ayush Srivastava\Documents\Machine Learning\reinforcement\algo.ipynb Cell 20 in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/Ayush%20Srivastava/Documents/Machine%20Learning/reinforcement/algo.ipynb#ch0000023?line=2'>3</a> txt = "Hello, Welcome to digipodium"
#       <a href='vscode-notebook-cell:/c%3A/Users/Ayush%20Srivastava/Documents/Machine%20Learning/reinforcement/algo.ipynb#ch0000023?line=3'>4</a> x = re.match(r"\bl\w+", txt)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Ayush%20Srivastava/Documents/Machine%20Learning/reinforcement/algo.ipynb#ch0000023?line=4'>5</a> print(x.group())
#
# AttributeError: 'NoneType' object has no attribute 'group'
